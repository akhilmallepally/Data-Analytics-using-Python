# %% [markdown]
# #     High level statistics of the dataset: number of points, numer of features, number of classes, data-points per class.
#     Explain our objective.
#     Perform Univaraite analysis(PDF, CDF, Boxplot, Voilin plots) to understand which features are useful towards classification.
#     Perform Bi-variate analysis (scatter plots, pair-plots) to see if combinations of features are useful in classfication.
#     Write your observations in english as crisply and unambigously as possible. Always quantify your results.

# %% [markdown]
# Objective : Given the features(age, year and nodes), classify it's status(1 or 2).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

hab = pd.read_csv("./haberman.csv")
print(hab.head())
# Out:
#    age  year  nodes  status
# 0   30    64      1       1
# 1   30    62      3       1
# 2   30    65      0       1
# 3   31    59      2       1
# 4   31    65      4       1

# %%
print(f'(rows, columns) : {hab.shape}') #rows represent no. of data points or observations ans columns represent features
print(f'column names in the dataset : {hab.columns}')
# Out:
# (rows, columns) : (306, 4)
# column names in the dataset : Index(['age', 'year', 'nodes', 'status'], dtype='object')

# %%
#(Q) No of datapoints for each class or label
#Here status is the class or label
print(hab["status"].value_counts())
# Out:
# 1    225
# 2     81
# Name: status, dtype: int64

# %%
hab.plot(kind='scatter', x = 'age', y = 'nodes')
plt.show()
#Data points are

# %%
sns.set_style("whitegrid")
sns.FacetGrid(hab, hue='status', height = 3) \
    .map(plt.scatter, "age", "nodes") \
    .add_legend()
plt.show()

# %%
#Pair Plot
plt.close()
sns.set_style("whitegrid")
sns.pairplot(hab, hue = "status", height = 3)
plt.show()

# %%
sns.FacetGrid(hab, hue = "status", height = 5) \
    .map(sns.distplot, "age") \
    .add_legend()
plt.show()
# Out:
# c:\users\s542403\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\s542403\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(hab, hue = "status", height = 5) \
    .map(sns.distplot, "nodes") \
    .add_legend()
plt.show()
# Out:
# c:\users\s542403\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\s542403\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(hab, hue = "status", height = 5) \
    .map(sns.distplot, "year") \
    .add_legend()
plt.show()
# Out:
# c:\users\s542403\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\s542403\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Visualising same with only histograms excluding the pdf curves
sns.FacetGrid(hab, hue ="status", height =5) \
    .map(sns.histplot, "year") \
    .add_legend()
plt.show()

# %%
sns.FacetGrid(hab, hue ="status", height = 5) #since we removed the backslash at the end we get an indentation error
    .map(sns.histplot, "nodes")
    .add_legend()
plt.show()
# Out:
#   File "<ipython-input-12-942525c164cb>", line 2
#     .map(sns.histplot, "nodes")
#     ^
# IndentationError: unexpected indent

# %%
sns.FacetGrid(hab, hue ="status", height = 5) \
    .map(sns.histplot, "nodes") \
    .add_legend()
plt.show()

# %%
sns.FacetGrid(hab, hue="status", height = 5) \
    .map(sns.histplot, "age") \
    .add_legend()
plt.show()

# %%
#Plotting 1D scatter plot
hab_one = hab.loc[hab["status"] == 1]
hab_two = hab.loc[hab["status"]==2]
print("******************")
print(hab_one["age"])
print("******************")
print(hab_one["nodes"])
print("******************")
print(hab_one["year"])
# Out:
# 0      30
# 1      30
# 2      30
# 3      31
# 4      31
#        ..
# 298    73
# 300    74
# 301    75
# 302    76
# 303    77
# Name: age, Length: 225, dtype: int64

# %%
#plotting 1D scatter plot
plt.plot(hab_one["age"])
